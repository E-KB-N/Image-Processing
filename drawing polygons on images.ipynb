# %%
#import libraries
from skimage import io
from skimage import draw

#Read imge
img = io.imread('0ld.jpg')
def rectangle(x,y,w,h):
    rr,cc = [x,x+w,x+w,x],[y,y,y+h,y+h]
    return (draw.polygon(rr,cc))
rr,cc = rectangle(10,10,100,100)
img[rr,cc]=1
io.imshow(img)
